# %%
# %run ../mlp/Model_Cifar10_MLP.ipynb

# %% [markdown]
# <h1 style="color:#987753"><center>============= CREATE LINEAR MODEL =============</center></h1>

# %%
def hyperParams():

    modelParams = {"Layers":[{"neurons":1, "activation":"tanh","dropOut":False},
#                     {"neurons":256, "activation":"sigmoid", "dropOut":False},
#                     {"neurons":256, "activation":"relu", "dropOut":0.3},
#                     {"neurons":128, "activation":"relu", "dropOut":False},
#                     {"neurons":256, "activation":"sigmoid", "dropOut":False},
#                     {"neurons":256, "activation":"relu", "dropOut":0.2},
                    {"neurons":10, "activation":"softmax", "dropOut":False}],
                   "loss":"categorical_crossentropy",
                   "optimizer":"Adam",
                   "metrics":"accuracy",
                   "epochs":100,
                   "batchSize":255
                 }
    return modelParams

# %%
def createLinearModel():
    
    model = Sequential()
    model.add(Flatten(input_shape= (32,32,3)))
    model.add(Dense(1, activation='tanh'))
    model.add(Dense(10, activation='softmax'))
    
    model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
                   optimizer="adam",
                   metrics=['accuracy'])
    model.summary()
    return model

# %%
def fitModel(model,trainImages, trainLabels, testImges, testLabels, epochs, batchSize):
    
    start_time = time.time()
    ################################ CALCULATE RUNTIME - START ###############################
    model.fit(trainImages, trainLabels,
                       epochs=epochs,
                       batch_size=batchSize, verbose=1, validation_data=(testImges, testLabels))
    ################################ CALCULATE RUNTIME - END ###############################
    print(humanizeTime(time.time() - start_time))
    return model, humanizeTime(time.time() - start_time)

# %%
def main():
    global ID
    ID = random.randint(1,1000000)
    print("================================ ID RUN %s ================================" % (ID))
    (trainImages, testImages, trainLabels, testLabels) = loadData()
    
    print("================================ SHAPE ================================")
    print("\t- NB TRAIN SAMPLES %s WIDTH %s HEIGHT %s COLOR %s" % (trainImages.shape))
    print("\t- NB TEST SAMPLES %s WIDTH %s HEIGHT %s COLOR %s" % (testImages.shape))
    
    print("================================ PLOT FIGURE ================================")
    plotFigure(trainImages, trainLabels, nbSamples=25)
    
    print("================================ ONEHOT ENCODING ================================")
    trainLabels, testLabels = oneHoteEncoding(trainLabels, testLabels)
    
    print("================================ CREATE MODEL ================================")
    model = createLinearModel()
    
    print("================================ RESHAPE INPUTS ================================")
    trainImages, testImages = reshapeInput(trainImages, testImages)
    
    print("================================ FIT MODEL ================================")
    epochs = 100
    batchSize = 1000
    model, runTime = fitModel(model, trainImages, trainLabels, testImages, testLabels, epochs, batchSize)
    
    print("================================ EVALUATE MODEL ================================")
    resultEV = evaluateModel(model, testImages, testLabels)
    
    print("================================ PREDICITION ================================")
    prediction, result = predictionPercent(model, testImages, testLabels)
    
    print("================================ PLOT PREDICITION ================================")
    plotPredictedResult(prediction, testImages, testLabels)
    
#     print("================================ SAVE MODEL ================================")
#     saveModel(model)
    
#     print("================================ GENERATE EXCEL HYPERPARAMS ================================")
#     jsonDf = generateExcelParams(params, resultEV, runTime)
#     jsonDf.head()

# %%
main()
# Out:
# ================================ ID RUN 2146 ================================
# ================================ SHAPE ================================
# 	- NB TRAIN SAMPLES 50000 WIDTH 32 HEIGHT 32 COLOR 3
# 	- NB TEST SAMPLES 10000 WIDTH 32 HEIGHT 32 COLOR 3
# ================================ PLOT FIGURE ================================
# ================================ ONEHOT ENCODING ================================
# ================================ CREATE MODEL ================================
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 3073
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                20
# =================================================================
# Total params: 3,093
# Trainable params: 3,093
# Non-trainable params: 0
# _________________________________________________________________
# ================================ RESHAPE INPUTS ================================
# ================================ FIT MODEL ================================
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1s 25us/sample - loss: 2.2866 - accuracy: 0.1275 - val_loss: 2.2641 - val_accuracy: 0.1407
# Epoch 2/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.2501 - accuracy: 0.1454 - val_loss: 2.2448 - val_accuracy: 0.1437
# Epoch 3/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.2362 - accuracy: 0.1487 - val_loss: 2.2322 - val_accuracy: 0.1500
# Epoch 4/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.2259 - accuracy: 0.1510 - val_loss: 2.2324 - val_accuracy: 0.1462
# Epoch 5/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.2198 - accuracy: 0.1517 - val_loss: 2.2179 - val_accuracy: 0.1509
# Epoch 6/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.2151 - accuracy: 0.1535 - val_loss: 2.2131 - val_accuracy: 0.1487
# Epoch 7/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.2116 - accuracy: 0.1544 - val_loss: 2.2092 - val_accuracy: 0.1526
# Epoch 8/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.2059 - accuracy: 0.1567 - val_loss: 2.2049 - val_accuracy: 0.1510
# Epoch 9/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.2047 - accuracy: 0.1544 - val_loss: 2.2048 - val_accuracy: 0.1524
# Epoch 10/100
# 50000/50000 [==============================] - 1s 18us/sample - loss: 2.2047 - accuracy: 0.1550 - val_loss: 2.1987 - val_accuracy: 0.1498
# Epoch 11/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1983 - accuracy: 0.1558 - val_loss: 2.1957 - val_accuracy: 0.1594
# Epoch 12/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1939 - accuracy: 0.1605 - val_loss: 2.1924 - val_accuracy: 0.1615
# Epoch 13/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1904 - accuracy: 0.1613 - val_loss: 2.1944 - val_accuracy: 0.1623
# Epoch 14/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1869 - accuracy: 0.1617 - val_loss: 2.1867 - val_accuracy: 0.1633
# Epoch 15/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1838 - accuracy: 0.1631 - val_loss: 2.1887 - val_accuracy: 0.1590
# Epoch 16/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1802 - accuracy: 0.1623 - val_loss: 2.1793 - val_accuracy: 0.1647
# Epoch 17/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1740 - accuracy: 0.1635 - val_loss: 2.1773 - val_accuracy: 0.1624
# Epoch 18/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1714 - accuracy: 0.1630 - val_loss: 2.1684 - val_accuracy: 0.1667
# Epoch 19/100
# 50000/50000 [==============================] - 1s 18us/sample - loss: 2.1649 - accuracy: 0.1673 - val_loss: 2.1641 - val_accuracy: 0.1677
# Epoch 20/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.1600 - accuracy: 0.1685 - val_loss: 2.1605 - val_accuracy: 0.1681
# Epoch 21/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1545 - accuracy: 0.1691 - val_loss: 2.1549 - val_accuracy: 0.1702
# Epoch 22/100
# 50000/50000 [==============================] - 1s 18us/sample - loss: 2.1535 - accuracy: 0.1684 - val_loss: 2.1500 - val_accuracy: 0.1713
# Epoch 23/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1447 - accuracy: 0.1709 - val_loss: 2.1448 - val_accuracy: 0.1704
# Epoch 24/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1392 - accuracy: 0.1691 - val_loss: 2.1395 - val_accuracy: 0.1706
# Epoch 25/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1347 - accuracy: 0.1708 - val_loss: 2.1353 - val_accuracy: 0.1703
# Epoch 26/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1339 - accuracy: 0.1685 - val_loss: 2.1299 - val_accuracy: 0.1706
# Epoch 27/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1283 - accuracy: 0.1707 - val_loss: 2.1281 - val_accuracy: 0.1752
# Epoch 28/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.1216 - accuracy: 0.1711 - val_loss: 2.1205 - val_accuracy: 0.1748
# Epoch 29/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1171 - accuracy: 0.1759 - val_loss: 2.1197 - val_accuracy: 0.1781
# Epoch 30/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1116 - accuracy: 0.1783 - val_loss: 2.1103 - val_accuracy: 0.1761
# Epoch 31/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.1072 - accuracy: 0.1787 - val_loss: 2.1063 - val_accuracy: 0.1784
# Epoch 32/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.1006 - accuracy: 0.1798 - val_loss: 2.1044 - val_accuracy: 0.1789
# Epoch 33/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0953 - accuracy: 0.1797 - val_loss: 2.0955 - val_accuracy: 0.1786
# Epoch 34/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0892 - accuracy: 0.1806 - val_loss: 2.0885 - val_accuracy: 0.1803
# Epoch 35/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0833 - accuracy: 0.1796 - val_loss: 2.0835 - val_accuracy: 0.1782
# Epoch 36/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0785 - accuracy: 0.1797 - val_loss: 2.0864 - val_accuracy: 0.1821
# Epoch 37/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0744 - accuracy: 0.1810 - val_loss: 2.0753 - val_accuracy: 0.1780
# Epoch 38/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0692 - accuracy: 0.1809 - val_loss: 2.0728 - val_accuracy: 0.1838
# Epoch 39/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0631 - accuracy: 0.1817 - val_loss: 2.0686 - val_accuracy: 0.1814
# Epoch 40/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0610 - accuracy: 0.1804 - val_loss: 2.0667 - val_accuracy: 0.1752
# Epoch 41/100
# 50000/50000 [==============================] - 1s 18us/sample - loss: 2.0575 - accuracy: 0.1805 - val_loss: 2.0585 - val_accuracy: 0.1790
# Epoch 42/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0565 - accuracy: 0.1795 - val_loss: 2.0674 - val_accuracy: 0.1822
# Epoch 43/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0564 - accuracy: 0.1792 - val_loss: 2.0534 - val_accuracy: 0.1796
# Epoch 44/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0504 - accuracy: 0.1813 - val_loss: 2.0520 - val_accuracy: 0.1844
# Epoch 45/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0470 - accuracy: 0.1827 - val_loss: 2.0492 - val_accuracy: 0.1850
# Epoch 46/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0454 - accuracy: 0.1852 - val_loss: 2.0471 - val_accuracy: 0.1874
# Epoch 47/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0437 - accuracy: 0.1834 - val_loss: 2.0464 - val_accuracy: 0.1857
# Epoch 48/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0453 - accuracy: 0.1847 - val_loss: 2.0460 - val_accuracy: 0.1862
# Epoch 49/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0411 - accuracy: 0.1851 - val_loss: 2.0477 - val_accuracy: 0.1844
# Epoch 50/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0425 - accuracy: 0.1835 - val_loss: 2.0430 - val_accuracy: 0.1862
# Epoch 51/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0404 - accuracy: 0.1843 - val_loss: 2.0454 - val_accuracy: 0.1823
# Epoch 52/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0370 - accuracy: 0.1845 - val_loss: 2.0400 - val_accuracy: 0.1880
# Epoch 53/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0375 - accuracy: 0.1850 - val_loss: 2.0397 - val_accuracy: 0.1871
# Epoch 54/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0361 - accuracy: 0.1853 - val_loss: 2.0408 - val_accuracy: 0.1856
# Epoch 55/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0349 - accuracy: 0.1854 - val_loss: 2.0408 - val_accuracy: 0.1870
# Epoch 56/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0358 - accuracy: 0.1856 - val_loss: 2.0370 - val_accuracy: 0.1880
# Epoch 57/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0433 - accuracy: 0.1836 - val_loss: 2.0381 - val_accuracy: 0.1869
# Epoch 58/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0327 - accuracy: 0.1850 - val_loss: 2.0367 - val_accuracy: 0.1878
# Epoch 59/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0312 - accuracy: 0.1870 - val_loss: 2.0379 - val_accuracy: 0.1888
# Epoch 60/100
# 50000/50000 [==============================] - 1s 18us/sample - loss: 2.0304 - accuracy: 0.1887 - val_loss: 2.0340 - val_accuracy: 0.1880
# Epoch 61/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0380 - accuracy: 0.1836 - val_loss: 2.0367 - val_accuracy: 0.1857
# Epoch 62/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0303 - accuracy: 0.1863 - val_loss: 2.0353 - val_accuracy: 0.1872
# Epoch 63/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0294 - accuracy: 0.1860 - val_loss: 2.0342 - val_accuracy: 0.1824
# Epoch 64/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0299 - accuracy: 0.1873 - val_loss: 2.0330 - val_accuracy: 0.1887
# Epoch 65/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0326 - accuracy: 0.1875 - val_loss: 2.0330 - val_accuracy: 0.1881
# Epoch 66/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0321 - accuracy: 0.1890 - val_loss: 2.0328 - val_accuracy: 0.1880
# Epoch 67/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0282 - accuracy: 0.1881 - val_loss: 2.0362 - val_accuracy: 0.1901
# Epoch 68/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0352 - accuracy: 0.1871 - val_loss: 2.0319 - val_accuracy: 0.1875
# Epoch 69/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0273 - accuracy: 0.1904 - val_loss: 2.0409 - val_accuracy: 0.1837
# Epoch 70/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0281 - accuracy: 0.1915 - val_loss: 2.0359 - val_accuracy: 0.1855
# Epoch 71/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0310 - accuracy: 0.1891 - val_loss: 2.0503 - val_accuracy: 0.1787
# Epoch 72/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0296 - accuracy: 0.1896 - val_loss: 2.0323 - val_accuracy: 0.1921
# Epoch 73/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0293 - accuracy: 0.1893 - val_loss: 2.0348 - val_accuracy: 0.1906
# Epoch 74/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0276 - accuracy: 0.1909 - val_loss: 2.0318 - val_accuracy: 0.1926
# Epoch 75/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0265 - accuracy: 0.1919 - val_loss: 2.0300 - val_accuracy: 0.1880
# Epoch 76/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0235 - accuracy: 0.1933 - val_loss: 2.0304 - val_accuracy: 0.1909
# Epoch 77/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0258 - accuracy: 0.1896 - val_loss: 2.0310 - val_accuracy: 0.1881
# Epoch 78/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0303 - accuracy: 0.1897 - val_loss: 2.0465 - val_accuracy: 0.1810
# Epoch 79/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0273 - accuracy: 0.1909 - val_loss: 2.0309 - val_accuracy: 0.1858
# Epoch 80/100
# 50000/50000 [==============================] - 1s 18us/sample - loss: 2.0240 - accuracy: 0.1927 - val_loss: 2.0294 - val_accuracy: 0.1910
# Epoch 81/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0295 - accuracy: 0.1899 - val_loss: 2.0294 - val_accuracy: 0.1885
# Epoch 82/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0257 - accuracy: 0.1924 - val_loss: 2.0290 - val_accuracy: 0.1898
# Epoch 83/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0215 - accuracy: 0.1931 - val_loss: 2.0279 - val_accuracy: 0.1889
# Epoch 84/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0251 - accuracy: 0.1932 - val_loss: 2.0288 - val_accuracy: 0.1902
# Epoch 85/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0259 - accuracy: 0.1905 - val_loss: 2.0286 - val_accuracy: 0.1898
# Epoch 86/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0245 - accuracy: 0.1910 - val_loss: 2.0418 - val_accuracy: 0.1915
# Epoch 87/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0281 - accuracy: 0.1906 - val_loss: 2.0342 - val_accuracy: 0.1875
# Epoch 88/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0207 - accuracy: 0.1939 - val_loss: 2.0280 - val_accuracy: 0.1921
# Epoch 89/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0211 - accuracy: 0.1924 - val_loss: 2.0279 - val_accuracy: 0.1892
# Epoch 90/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0257 - accuracy: 0.1919 - val_loss: 2.0345 - val_accuracy: 0.1859
# Epoch 91/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0218 - accuracy: 0.1940 - val_loss: 2.0343 - val_accuracy: 0.1870
# Epoch 92/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0238 - accuracy: 0.1936 - val_loss: 2.0345 - val_accuracy: 0.1864
# Epoch 93/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0214 - accuracy: 0.1932 - val_loss: 2.0270 - val_accuracy: 0.1893
# Epoch 94/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0213 - accuracy: 0.1945 - val_loss: 2.0286 - val_accuracy: 0.1890
# Epoch 95/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0218 - accuracy: 0.1915 - val_loss: 2.0366 - val_accuracy: 0.1933
# Epoch 96/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0265 - accuracy: 0.1914 - val_loss: 2.0289 - val_accuracy: 0.1859
# Epoch 97/100
# 50000/50000 [==============================] - 1s 16us/sample - loss: 2.0212 - accuracy: 0.1931 - val_loss: 2.0331 - val_accuracy: 0.1887
# Epoch 98/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0192 - accuracy: 0.1927 - val_loss: 2.0343 - val_accuracy: 0.1872
# Epoch 99/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0218 - accuracy: 0.1931 - val_loss: 2.0561 - val_accuracy: 0.1838
# Epoch 100/100
# 50000/50000 [==============================] - 1s 17us/sample - loss: 2.0213 - accuracy: 0.1930 - val_loss: 2.0363 - val_accuracy: 0.1869
# RUN TIME : 00:01:23
# ================================ EVALUATE MODEL ================================
# 10000/10000 [==============================] - 0s 35us/sample - loss: 2.0363 - accuracy: 0.1869
# ================================ PREDICITION ================================
# Predicted percent 18.69 %
# ================================ PLOT PREDICITION ================================
